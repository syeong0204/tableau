# %%
import pandas as pd

# %%
file_to_load = 'Resource\JC-202101-citibike-tripdata.csv'

# %%
jan21 = pd.read_csv(file_to_load)
jan21
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               266  2021-01-01 00:03:35.5100  2021-01-01 00:08:01.7770
# 1              1543  2021-01-01 00:23:32.9250  2021-01-01 00:49:16.0830
# 2              1461  2021-01-01 00:23:50.7940  2021-01-01 00:48:12.5660
# 3               793  2021-01-01 00:31:09.0770  2021-01-01 00:44:22.9430
# 4               596  2021-01-01 00:35:52.1900  2021-01-01 00:45:48.7740
# ...             ...                       ...                       ...
# 11619          2476  2021-01-31 20:16:05.4700  2021-01-31 20:57:22.0110
# 11620           147  2021-01-31 21:05:05.2090  2021-01-31 21:07:32.8660
# 11621           660  2021-01-31 21:06:23.5880  2021-01-31 21:17:23.8420
# 11622           384  2021-01-31 21:16:37.8220  2021-01-31 21:23:02.1240
# 11623           356  2021-01-31 23:24:50.8810  2021-01-31 23:30:47.3030
#
#        start station id start station name  start station latitude  \
# ...

# %%
jan21_df = jan21.rename(columns = {
    'starttime': 'started_at', 'stoptime': 'ended_at', 'start station name': 'start_station_name', 'end station name': 'end_station_name',
    'end station id': 'end_station_id', 'start station latitude': 'start_lat', 'start station longitude': 'start_lng',
    'end station id': 'end_station_id', 'end station name': 'end_station_name', 'end station lattitude': 'end_lat',
    'end station longitude': 'end_lng', 'usertype': 'member_casual'
})
jan21_df
# Out:
#        tripduration                started_at                  ended_at  \
# 0               266  2021-01-01 00:03:35.5100  2021-01-01 00:08:01.7770
# 1              1543  2021-01-01 00:23:32.9250  2021-01-01 00:49:16.0830
# 2              1461  2021-01-01 00:23:50.7940  2021-01-01 00:48:12.5660
# 3               793  2021-01-01 00:31:09.0770  2021-01-01 00:44:22.9430
# 4               596  2021-01-01 00:35:52.1900  2021-01-01 00:45:48.7740
# ...             ...                       ...                       ...
# 11619          2476  2021-01-31 20:16:05.4700  2021-01-31 20:57:22.0110
# 11620           147  2021-01-31 21:05:05.2090  2021-01-31 21:07:32.8660
# 11621           660  2021-01-31 21:06:23.5880  2021-01-31 21:17:23.8420
# 11622           384  2021-01-31 21:16:37.8220  2021-01-31 21:23:02.1240
# 11623           356  2021-01-31 23:24:50.8810  2021-01-31 23:30:47.3030
#
#        start station id start_station_name  start_lat  start_lng  \
# ...

# %%
membs = jan21_df['member_casual']

# %%
membs
# Out:
# 0        Subscriber
# 1          Customer
# 2          Customer
# 3          Customer
# 4          Customer
#             ...
# 11619    Subscriber
# 11620    Subscriber
# 11621    Subscriber
# 11622    Subscriber
# 11623    Subscriber
# Name: member_casual, Length: 11624, dtype: object

# %%
for name in range(len(membs)):
    if membs[name] == 'Subscriber':
        membs[name] = 'member'
# Out:
# C:\Users\syeong\AppData\Local\Temp/ipykernel_19372/4122753542.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   membs[name] = 'member'

# %%
for name in range(len(membs)):
    if membs[name] == 'Customer':
        membs[name] = 'casual'
# Out:
# C:\Users\syeong\AppData\Local\Temp/ipykernel_19372/2610021920.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   membs[name] = 'casual'

# %%
membs
# Out:
# 0        member
# 1        casual
# 2        casual
# 3        casual
# 4        casual
#           ...
# 11619    member
# 11620    member
# 11621    member
# 11622    member
# 11623    member
# Name: member_casual, Length: 11624, dtype: object

# %%
jan21_df.to_csv(r'JC-202101-citibike-tripdata.csv')
